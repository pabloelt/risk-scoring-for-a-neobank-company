# %% [markdown]
# # EDA

# %% [markdown]
# ## IMPORTAR PAQUETES

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set_style("darkgrid")

#Automcompletar rápido
# %config IPCompleter.greedy=True

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## IMPORTAR LOS DATOS

# %% [markdown]
# Sustituir la ruta del proyecto.

# %%
ruta_proyecto = 'C:/Users/pelop/OneDrive/Desktop/Curso Data Science Pedro/2 CURSO DATA SCIENCE/03_MACHINE_LEARNING/07_CASOS/03_RIESGOS'

# %% [markdown]
# Nombres de los ficheros de datos.

# %%
nombre_cat = 'cat_resultado_calidad.pickle'
nombre_num = 'num_resultado_calidad.pickle'

# %% [markdown]
# Cargar los datos.

# %%
cat = pd.read_pickle(ruta_proyecto + '/02_Datos/03_Trabajo/' + nombre_cat)
num = pd.read_pickle(ruta_proyecto + '/02_Datos/03_Trabajo/' + nombre_num)

# %% [markdown]
# ## EDA CATEGÓRICAS

# %% [markdown]
# ### Análisis estadístico

# %%
variables = ['antigüedad_empleo', 'ingresos_verificados', 'rating', 'vivienda',
       'finalidad', 'num_cuotas', 'estado']

# %%
def frecuencias_cat(df_cat):
    resultado = df_cat[variables].apply(lambda x: x.value_counts(normalize = True)).T.stack()\
                .to_frame().reset_index()\
                .rename(columns={'level_0':'Variable','level_1':'Valor',0: "Frecuencia"})\
                .sort_values(by = ['Variable','Frecuencia'])
    return(resultado)

# %%
frecuencias_cat(cat)
# Out:
#                 Variable                                              Valor  \
# 9      antigüedad_empleo                                            9 years
# 8      antigüedad_empleo                                            8 years
# 7      antigüedad_empleo                                            7 years
# 6      antigüedad_empleo                                            6 years
# 4      antigüedad_empleo                                            4 years
# 5      antigüedad_empleo                                            5 years
# 0      antigüedad_empleo                                             1 year
# 11     antigüedad_empleo                                        desconocido
# 3      antigüedad_empleo                                            3 years
# 10     antigüedad_empleo                                           < 1 year
# 2      antigüedad_empleo                                            2 years
# 1      antigüedad_empleo                                          10+ years
# 46                estado                                            Default
# 47                estado  Does not meet the credit policy. Status:Charge...
# 48                estado  Does not meet the credit policy. Status:Fully ...
# 51                estado                                  Late (16-30 days)
# 50                estado                                    In Grace Period
# 52                estado                                 Late (31-120 days)
# 44                estado                                        Charged Off
# 45                estado                                            Current
# 49                estado                                         Fully Paid
# 31             finalidad                                        educational
# 38             finalidad                                   renewable_energy
# 41             finalidad                                            wedding
# 33             finalidad                                              house
# 36             finalidad                                             moving
# 40             finalidad                                           vacation
# 28             finalidad                                                car
# 39             finalidad                                     small_business
# 35             finalidad                                            medical
# 34             finalidad                                     major_purchase
# 37             finalidad                                              other
# 32             finalidad                                   home_improvement
# 29             finalidad                                        credit_card
# 30             finalidad                                 debt_consolidation
# 14  ingresos_verificados                                           Verified
# 12  ingresos_verificados                                       Not Verified
# 13  ingresos_verificados                                    Source Verified
# 43            num_cuotas                                          60 months
# 42            num_cuotas                                          36 months
# 21                rating                                                  G
# 20                rating                                                  F
# 19                rating                                                  E
# 18                rating                                                  D
# 15                rating                                                  A
# 17                rating                                                  C
# 16                rating                                                  B
# 24              vivienda                                               NONE
# 25              vivienda                                              OTHER
# 22              vivienda                                                ANY
# 26              vivienda                                                OWN
# 27              vivienda                                               RENT
# 23              vivienda                                           MORTGAGE
#
#     Frecuencia
# 9     0.035584
# 8     0.041084
# 7     0.042019
# 6     0.045146
# 4     0.060813
# 5     0.062331
# 0     0.064977
# 11    0.065077
# 3     0.080831
# 10    0.084447
# 2     0.088927
# 1     0.328765
# 46    0.000022
# 47    0.000417
# 48    0.000777
# 51    0.001862
# 50    0.003854
# 52    0.009577
# 44    0.117831
# 45    0.388299
# 49    0.477362
# 31    0.000194
# 38    0.000611
# 41    0.001114
# 33    0.006658
# 36    0.006852
# 40    0.007147
# 28    0.010224
# 39    0.011303
# 35    0.012086
# 34    0.023051
# 37    0.062352
# 32    0.065494
# 29    0.226487
# 30    0.566425
# 14    0.276738
# 12    0.332806
# 13    0.390456
# 43    0.286617
# 42    0.713383
# 21    0.005493
# 20    0.018716
# 19    0.059879
# 18    0.143542
# 15    0.192068
# 17    0.288070
# 16    0.292233
# 24    0.000022
# 25    0.000086
# 22    0.000417
# 26    0.111237
# 27    0.398430
# 23    0.489808

# %% [markdown]
# ### Análisis gráfico

# %%
def graficos_eda_categoricos(cat):

    my_cmap = plt.get_cmap("Blues")
    rescale = lambda y: (y - np.min(y)) / (np.max(y) - np.min(y))
    
    #Calculamos el número de filas que necesitamos
    from math import ceil
    filas = ceil(cat.shape[1] / 3)

    #Definimos el gráfico
    f, ax = plt.subplots(nrows = filas, ncols = 3, figsize = (10, filas * 4.5))

    #Aplanamos para iterar por el gráfico como si fuera de 1 dimensión en lugar de 2
    ax = ax.flat 

    #Creamos el bucle que va añadiendo gráficos
    for cada, variable in enumerate(cat):
        y = cat[variable].value_counts()
        cat[variable].value_counts().plot.bar(ax = ax[cada], color=my_cmap(rescale(y)+0.4))
        ax[cada].set_title(variable, fontsize = 9, fontweight = "bold")
        ax[cada].tick_params(labelsize = 7)
        ax[cada].set_xlabel('')
    
    plt.tight_layout()
    plt.savefig('exhibit_1.png')

# %%
variables2 = ['antigüedad_empleo', 'ingresos_verificados', 'rating', 'vivienda',
       'finalidad', 'estado']
graficos_eda_categoricos(cat[variables2])

# %% [markdown]
# Conclusiones:
#
# En transformación:
#
# * En vivienda juntar ANY, NONE y OTHER a la categoria mayoritaria
# * En finalidad juntar renewable_energy, educational y wedding en 'otros'
# * Crear la target a partir de estado

# %%
my_cmap = plt.get_cmap("Blues")
rescale = lambda y: (y - np.min(y)) / (np.max(y) - np.min(y))
y = cat.empleo.value_counts()

cat.empleo.value_counts().sort_values(ascending = False)[0:15].plot.barh(figsize = (7,5), color=my_cmap(rescale(y)+0.4));
plt.title('empleo', fontsize = 9, fontweight = "bold")
plt.ylabel('')
plt.tick_params(labelsize = 7)
plt.gca().invert_yaxis();
plt.tight_layout()
plt.savefig('exhibit_2.png')

# %% [markdown]
# ## EDA NUMÉRICAS

# %% [markdown]
# ### Análisis estadístico

# %%
def estadisticos_cont(num):
    #Calculamos describe
    estadisticos = num.describe().T
    #Añadimos la mediana
    estadisticos['median'] = num.median()
    #Reordenamos para que la mediana esté al lado de la media
    estadisticos = estadisticos.iloc[:,[0,1,8,2,3,4,5,6,7]]
    #Lo devolvemos
    return(estadisticos)

# %%
estadisticos_cont(num)
# Out:
#                                 count          mean    median           std  \
# ingresos                     139081.0  75176.136800  65000.00  42343.522582
# dti                          139081.0     18.849986     17.82     14.671438
# num_hipotecas                139081.0      1.503857      1.00      1.876064
# num_lineas_credito           139081.0     11.607718     11.00      5.628493
# porc_tarjetas_75p            139081.0     41.110100     33.30     36.476757
# porc_uso_revolving           139081.0     50.338626     50.40     24.678836
# num_cancelaciones_12meses    139081.0      0.008463      0.00      0.104095
# num_derogatorios             139081.0      0.198129      0.00      0.570424
# num_meses_desde_ult_retraso  139081.0     16.826705      0.00     23.035208
# principal                    139081.0  14975.111985  12800.00   9131.483146
# tipo_interes                 139081.0     13.093626     12.62      4.835084
# imp_cuota                    139081.0    444.132784    377.37    265.726550
# imp_amortizado               139081.0   9472.750795   7000.00   8261.330350
# imp_recuperado               139081.0    144.296991      0.00    765.350965
#
#                                  min       25%       50%       75%        max
# ingresos                        0.00  46000.00  65000.00  92000.00  300000.00
# dti                             0.00     11.98     17.82     24.48     999.00
# num_hipotecas                   0.00      0.00      1.00      2.00      32.00
# num_lineas_credito              0.00      8.00     11.00     14.00      91.00
# porc_tarjetas_75p               0.00      0.00     33.30     66.70     100.00
# porc_uso_revolving              0.00     31.70     50.40     69.30     184.60
# num_cancelaciones_12meses       0.00      0.00      0.00      0.00       7.00
# num_derogatorios                0.00      0.00      0.00      0.00      46.00
# num_meses_desde_ult_retraso     0.00      0.00      0.00     31.00     195.00
# principal                    1000.00   8000.00  12800.00  20000.00   40000.00
# tipo_interes                    5.31      9.49     12.62     15.99      30.99
# imp_cuota                       7.61    251.06    377.37    589.22    1714.54
# imp_amortizado                  0.00   3011.48   7000.00  13761.00   40000.00
# imp_recuperado                  0.00      0.00      0.00      0.00   33666.34

# %% [markdown]
# Las variables dti (debt to income) y porc_uso_revolving no deberían ser inferior a 0 ni superior a 100. Aplicamos una winsorización manual para corregirlo.

# %%
num['dti'].clip(0,100, inplace=True)
num['porc_uso_revolving'].clip(0,100, inplace=True)
estadisticos_cont(num)
# Out:
#                                 count          mean    median           std  \
# ingresos                     139081.0  75176.136800  65000.00  42343.522582
# dti                          139081.0     18.674362     17.82      9.661924
# num_hipotecas                139081.0      1.503857      1.00      1.876064
# num_lineas_credito           139081.0     11.607718     11.00      5.628493
# porc_tarjetas_75p            139081.0     41.110100     33.30     36.476757
# porc_uso_revolving           139081.0     50.329025     50.40     24.656007
# num_cancelaciones_12meses    139081.0      0.008463      0.00      0.104095
# num_derogatorios             139081.0      0.198129      0.00      0.570424
# num_meses_desde_ult_retraso  139081.0     16.826705      0.00     23.035208
# principal                    139081.0  14975.111985  12800.00   9131.483146
# tipo_interes                 139081.0     13.093626     12.62      4.835084
# imp_cuota                    139081.0    444.132784    377.37    265.726550
# imp_amortizado               139081.0   9472.750795   7000.00   8261.330350
# imp_recuperado               139081.0    144.296991      0.00    765.350965
#
#                                  min       25%       50%       75%        max
# ingresos                        0.00  46000.00  65000.00  92000.00  300000.00
# dti                             0.00     11.98     17.82     24.48     100.00
# num_hipotecas                   0.00      0.00      1.00      2.00      32.00
# num_lineas_credito              0.00      8.00     11.00     14.00      91.00
# porc_tarjetas_75p               0.00      0.00     33.30     66.70     100.00
# porc_uso_revolving              0.00     31.70     50.40     69.30     100.00
# num_cancelaciones_12meses       0.00      0.00      0.00      0.00       7.00
# num_derogatorios                0.00      0.00      0.00      0.00      46.00
# num_meses_desde_ult_retraso     0.00      0.00      0.00     31.00     195.00
# principal                    1000.00   8000.00  12800.00  20000.00   40000.00
# tipo_interes                    5.31      9.49     12.62     15.99      30.99
# imp_cuota                       7.61    251.06    377.37    589.22    1714.54
# imp_amortizado                  0.00   3011.48   7000.00  13761.00   40000.00
# imp_recuperado                  0.00      0.00      0.00      0.00   33666.34

# %% [markdown]
# ### Análisis gráfico

# %%
def graficos_eda_continuas(num):
    
    #Calculamos el número de fila que necesitamos
    from math import ceil
    filas = ceil(num.shape[1] / 4)

    #Definimos el gráfico
    f, ax = plt.subplots(nrows = filas, ncols = 4, figsize = (10, filas * 2.5))

    #Aplanamos para iterar por el gráfico como si fuera de 1 dimensión en lugar de 2
    ax = ax.flat 

    #Creamos el bucle que va añadiendo gráficos
    for cada, variable in enumerate(num):
        num[variable].plot.density(ax = ax[cada])
        ax[cada].set_title(variable, fontsize = 9, fontweight = "bold")
        ax[cada].tick_params(labelsize = 8)
        ax[cada].set_ylabel('')
        
    plt.tight_layout()

# %%
graficos_eda_continuas(num)
plt.savefig('exhibit_3.png')

# %% [markdown]
# Vamos a analizar el detalle de imp_amortizado e imp_recuperado, ya que son relevantes para la target del modelo LGD.

# %%
ratios = num[['principal','imp_amortizado','imp_recuperado']].copy()

# %%
ratios['r_amortizado_principal'] = ratios.imp_amortizado / ratios.principal
ratios['r_recuperado_principal'] = ratios.imp_recuperado / ratios.principal

# %%
ratios.describe().T
# Out:
#                            count          mean          std     min  \
# principal               139081.0  14975.111985  9131.483146  1000.0
# imp_amortizado          139081.0   9472.750795  8261.330350     0.0
# imp_recuperado          139081.0    144.296991   765.350965     0.0
# r_amortizado_principal  139081.0      0.663204     0.368981     0.0
# r_recuperado_principal  139081.0      0.008975     0.041523     0.0
#
#                                 25%           50%      75%           max
# principal               8000.000000  12800.000000  20000.0  40000.000000
# imp_amortizado          3011.480000   7000.000000  13761.0  40000.000000
# imp_recuperado             0.000000      0.000000      0.0  33666.340000
# r_amortizado_principal     0.276246      0.873463      1.0      1.000032
# r_recuperado_principal     0.000000      0.000000      0.0      1.220774

# %% [markdown]
# Conclusiones:
#
# * En transformación convertir num_derogatorios a binaria
# * Revisar en profundidad la relación entre estado e imp_recuperado

# %%
temp = cat[['estado']].merge(num[['imp_recuperado']], left_index=True, right_index=True)
temp.groupby('estado').imp_recuperado.mean()
# Out:
# estado
# Charged Off                                            1222.837343
# Current                                                   0.000000
# Default                                                   0.000000
# Does not meet the credit policy. Status:Charged Off     501.922414
# Does not meet the credit policy. Status:Fully Paid        0.000000
# Fully Paid                                                0.000000
# In Grace Period                                           0.000000
# Late (16-30 days)                                         0.000000
# Late (31-120 days)                                        0.000000
# Name: imp_recuperado, dtype: float64

# %% [markdown]
# Efectivamente sólo hay importe recuperado en el estado Charged Off.

# %% [markdown]
# ## GUARDAR DATASETS TRAS EDA

# %% [markdown]
# Guarda los avances en cat y num con un sufijo para poder guardar o recuperar avances del proyecto.
#
# En formato pickle para no perder las modificaciones de metadatos.
#
# *NOTA: En algunos casos no hay cambios en los ficheros en esta fase, así que este paso es opcional.Pero si no guardas estos ficheros acuérdate de modificar la importación en el siguiente notebook.*

# %%
#Definir los nombres de los archivos
ruta_cat = ruta_proyecto + '/02_Datos/03_Trabajo/' + 'cat_resultado_eda.pickle'
ruta_num = ruta_proyecto + '/02_Datos/03_Trabajo/' + 'num_resultado_eda.pickle'

# %%
#Guardar los archivos
cat.to_pickle(ruta_cat)
num.to_pickle(ruta_num)
